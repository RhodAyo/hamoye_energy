# %% [markdown]
# Team Gender

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("COVID clinical trials.csv")

# %%
data.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# ...

# %%
#Gives a proper description of the columns in a transposed form
data.T
# Out:
#                                                                       0     \
# Rank                                                                     1
# NCT Number                                                     NCT04785898
# Title                    Diagnostic Performance of the ID Now™ COVID-19...
# Acronym                                                        COVID-IDNow
# Status                                              Active, not recruiting
# Study Results                                         No Results Available
# Conditions                                                         Covid19
# Interventions             Diagnostic Test: ID Now™ COVID-19 Screening Test
# Outcome Measures         Evaluate the diagnostic performance of the ID ...
# Sponsor/Collaborators                Groupe Hospitalier Paris Saint Joseph
# Gender                                                                 All
# ...

# %%
data.describe()
# Out:
#               Rank    Enrollment
# count  5783.000000  5.749000e+03
# mean   2892.000000  1.831949e+04
# std    1669.552635  4.045437e+05
# min       1.000000  0.000000e+00
# 25%    1446.500000  6.000000e+01
# 50%    2892.000000  1.700000e+02
# 75%    4337.500000  5.600000e+02
# max    5783.000000  2.000000e+07

# %%
#number of columns =27, and rows = 5783
data.shape
# Out:
# (5783, 27)

# %%
#shows presence of null values in COVID trials
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
#describes what columns are null with counts and types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5783 entries, 0 to 5782
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     5783 non-null   int64
#  1   NCT Number               5783 non-null   object
#  2   Title                    5783 non-null   object
#  3   Acronym                  2480 non-null   object
#  4   Status                   5783 non-null   object
#  5   Study Results            5783 non-null   object
#  6   Conditions               5783 non-null   object
#  7   Interventions            4897 non-null   object
#  8   Outcome Measures         5748 non-null   object
#  9   Sponsor/Collaborators    5783 non-null   object
#  10  Gender                   5773 non-null   object
#  11  Age                      5783 non-null   object
#  12  Phases                   3322 non-null   object
#  13  Enrollment               5749 non-null   float64
# ...

# %%
data['Gender'].unique()
# Out:
# array(['All', 'Female', 'Male', nan], dtype=object)

# %%
gender = data[['Gender']]

# %%
gender.describe()
# Out:
#        Gender
# count    5773
# unique      3
# top       All
# freq     5567

# %%
#check for null values and its sum
gender.isnull().sum()
# Out:
# Gender    10
# dtype: int64

# %%
data['Gender'].value_counts(dropna=False)
# Out:
# All       5567
# Female     162
# Male        44
# NaN         10
# Name: Gender, dtype: int64

# %%
data.groupby('Gender').mean()
# Out:
#                Rank    Enrollment
# Gender
# All     2875.503862  18984.795122
# Female  3367.327160   1365.456790
# Male    3147.159091    260.886364

# %%
data.groupby('Gender').sum()
# Out:
#             Rank   Enrollment
# Gender
# All     16007930  105080841.0
# Female    545507     221204.0
# Male      138475      11479.0

# %%
data.groupby('Gender').mean().plot(title="Pictoral display of the mean of Gender by rank and Enrollment")
# Out:
# <AxesSubplot:title={'center':'Pictoral display of the mean of Gender by rank and Enrollment'}, xlabel='Gender'>

# %%
data['Gender'].value_counts(dropna=False).plot(kind="bar", title="Counts of Gender available")
# Out:
# <AxesSubplot:title={'center':'Counts of Gender available'}>

# %%
#representing null values with the most popular type = All
data['Gender']=data['Gender'].fillna(data['Gender'].mode()[0])

# %%
#check for null values
data['Gender'].isnull().sum()
# Out:
# 0

# %%
data['Gender'].value_counts(dropna=False)
# Out:
# All       5577
# Female     162
# Male        44
# Name: Gender, dtype: int64

# %%
data['Gender'].value_counts(dropna=False).plot(kind="bar", title="Counts of Gender available")
# Out:
# <AxesSubplot:title={'center':'Counts of Gender available'}>
